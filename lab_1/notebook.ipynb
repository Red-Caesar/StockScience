# %%
# !python3 -m pip install -r requirements.txt >> install_logs.txt

# %%
import yfinance as yf

# %%
ticker = yf.Ticker('FIVE')
ticker.history(period="1mo")
# Out:
# /home/susbar/Documents/HSE/4_year/StockScience/.hse_stocks/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
#                                  Open        High         Low       Close  \
# Date
# 2023-12-26 00:00:00-05:00  204.580002  210.570007  203.619995  210.360001
# 2023-12-27 00:00:00-05:00  210.360001  213.690002  210.160004  212.699997
# 2023-12-28 00:00:00-05:00  213.009995  215.820007  212.770004  213.839996
# 2023-12-29 00:00:00-05:00  213.820007  214.600006  211.449997  213.160004
# 2024-01-02 00:00:00-05:00  210.860001  216.179993  210.539993  215.509995
# 2024-01-03 00:00:00-05:00  213.160004  214.570007  204.289993  204.690002
# 2024-01-04 00:00:00-05:00  205.350006  207.970001  203.990005  204.960007
# ...
